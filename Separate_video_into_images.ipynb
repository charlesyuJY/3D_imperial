# %%
# !pip3 install opencv-contrib-python
from platform import python_version

print(python_version())
import cv2
def extractImages(pathIn, pathOut):
    count = 0
    vidcap = cv2.VideoCapture(pathIn)
    success,image = vidcap.read()
    success = True
    while success:
        vidcap.set(cv2.CAP_PROP_POS_MSEC,(count*280))    # added this line 
        success,image = vidcap.read()
        print ('Read a new frame: ', success)
        cv2.imwrite( pathOut + "/frame%d.jpg" % count, image)     # save frame as JPEG file
        count = count + 1
# Out:
# 3.9.1

# %%
extractImages('VIRB_V0560140_Stitched_V1/VIRB_V0560140_Stitched_V1.mp4','Imperial_walkway')
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
# Downsample frames
# import os

# exist=True
# count = 0
# while exist:
#     count += 1
#     if count%10==1:
#         count+=1
#         continue
#     else:
#         if os.path.exists("my_stairs_frame/frame%d.jpg" %count):
#           os.remove("my_stairs_frame/frame%d.jpg"%count)
#           print("exist frame%d.jpg" %count)
#           count += 1
#         else:
#           print("The file does not exist")
#           break
# Out:
# exist frame2.jpg
# exist frame4.jpg
# exist frame6.jpg
# exist frame8.jpg
# exist frame10.jpg
# exist frame12.jpg
# exist frame14.jpg
# exist frame16.jpg
# exist frame18.jpg
# exist frame20.jpg
# exist frame22.jpg
# exist frame24.jpg
# exist frame26.jpg
# exist frame28.jpg
# exist frame30.jpg
# exist frame32.jpg
# exist frame34.jpg
# exist frame36.jpg
# exist frame38.jpg
# exist frame40.jpg
# exist frame42.jpg
# exist frame44.jpg
# exist frame46.jpg
# exist frame48.jpg
# exist frame50.jpg
# exist frame52.jpg
# exist frame54.jpg
# exist frame56.jpg
# exist frame58.jpg
# exist frame60.jpg
# exist frame62.jpg
# exist frame64.jpg
# exist frame66.jpg
# exist frame68.jpg
# exist frame70.jpg
# exist frame72.jpg
# exist frame74.jpg
# exist frame76.jpg
# exist frame78.jpg
# exist frame80.jpg
# exist frame82.jpg
# exist frame84.jpg
# exist frame86.jpg
# exist frame88.jpg
# exist frame90.jpg
# exist frame92.jpg
# exist frame94.jpg
# exist frame96.jpg
# exist frame98.jpg
# exist frame100.jpg
# ...

# %%
# !pip3 list
# Out:
# Package               Version
# --------------------- --------
# numpy                 1.19.5
# opencv-contrib-python 4.5.1.48
# opencv-python         4.5.1.48
# pip                   20.3.1
# setuptools            51.0.0
# TBB                   0.1
# wheel                 0.36.1
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
